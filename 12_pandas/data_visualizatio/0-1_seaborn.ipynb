# %% [markdown]
# # Seaborn 기본 문법

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
# matplotlib 데이터
year = [2018, 2019, 2020, 2021, 2022, 2023]
python = [5.8, 8.17, 9.31, 11.87, 15.63, 14.51]
C = [13.59, 14.08, 16.72, 14.32, 12.71, 14.73]
java = [15.78, 15.04, 16.73, 11.23, 10.82, 13.23]
JS = [3.49, 2.51, 2.38, 2.44, 2.12, 2.1]

# %% [markdown]
# ## 그래프 그리기

# %%
sns.lineplot(x=year, y=python)
# Out:
# <Axes: >

# %%
# matplotlib 기반으로 개발된 라이브러리이기 때문에 matplotlib 매개변수 대부분을 사용 가능
sns.lineplot(x=year, y=python, label='python')
sns.lineplot(x=year, y=java, label='Java')
# Out:
# <Axes: >

# %%
# sns.lineplot()은 matplotlib.axes를 반환하는 함수이다.
# matplotlib.axes 메소드를 이용해 그래프의 모양을 조절할 수 있다.
lp = sns.lineplot(x=year, y=python, label='python')

lp.set_xlabel('년도')
lp.set_ylabel('점유율')
# Out:
# Text(0, 0.5, '점유율')

# %% [markdown]
# ## 테마 사용하기

# %%
sns.set_style("ticks","darkgrid")
lp = sns.lineplot(x=year, y=python, label='Python')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.set_style("ticks","darkgrid")
#       2 lp = sns.lineplot(x=year, y=python, label='Python')
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\seaborn\rcmod.py:331, in set_style(style, rc)
#     303 def set_style(style=None, rc=None):
#     304     """
#     305     Set the parameters that control the general style of the plots.
#     306
#    (...)    329
#     330     """
# --> 331     style_object = axes_style(style, rc)
#     332     mpl.rcParams.update(style_object)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\seaborn\rcmod.py:294, in axes_style(style, rc)
#     292 # Override these settings with the provided rc dictionary
#     293 if rc is not None:
# --> 294     rc = {k: v for k, v in rc.items() if k in _style_keys}
#     295     style_dict.update(rc)
#     297 # Wrap in an _AxesStyle object so this can be used in a with statement
#
# AttributeError: 'str' object has no attribute 'items'
