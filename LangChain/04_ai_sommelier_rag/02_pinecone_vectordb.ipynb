# %% [markdown]
# ### Pinecone Vector DB

# %%
from dotenv import load_dotenv
load_dotenv()


# 파일 로드
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader('./winemag-data-130k-v2.csv', encoding='utf-8')

documents = loader.load()   # 모든 행을 Document 객체 리스트로 변환

print(len(documents))
print(documents[0])
# Out:
# 129971
# page_content=': 0
# country: Italy
# description: Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.
# designation: Vulkà Bianco
# points: 87
# price:
# province: Sicily & Sardinia
# region_1: Etna
# region_2:
# taster_name: Kerin O’Keefe
# taster_twitter_handle: @kerinokeefe
# title: Nicosia 2013 Vulkà Bianco  (Etna)
# variety: White Blend
# winery: Nicosia' metadata={'source': './winemag-data-130k-v2.csv', 'row': 0}

# %%
# 임베딩 모델 생성
from langchain_openai.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model='text-embedding-3-small')

# %%
# %pip install langchain-pinecone
# Out:
# Requirement already satisfied: langchain-pinecone in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (0.2.13)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.34 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-pinecone) (1.2.5)
# Requirement already satisfied: pinecone<8.0.0,>=6.0.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (7.3.0)
# Requirement already satisfied: numpy!=2.0.2,>=1.26.4 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-pinecone) (2.3.5)
# Requirement already satisfied: langchain-openai>=0.3.11 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-pinecone) (1.1.6)
# Requirement already satisfied: httpx>=0.28.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-pinecone) (0.28.1)
# Requirement already satisfied: simsimd>=5.9.11 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-pinecone) (6.5.12)
# Requirement already satisfied: pydantic>=2.11.1 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-pinecone) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (0.5.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (0.25.0)
# Requirement already satisfied: anyio in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (4.12.0)
# Requirement already satisfied: certifi in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (1.0.9)
# Requirement already satisfied: idna in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from httpcore==1.*->httpx>=0.28.0->langchain-pinecone) (0.16.0)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.3.0)
# Requirement already satisfied: aiohttp>=3.9.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.13.2)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pydantic>=2.11.1->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pydantic>=2.11.1->langchain-pinecone) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from pydantic>=2.11.1->langchain-pinecone) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.34->langchain-pinecone) (3.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.22.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (2.11.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai>=0.3.11->langchain-pinecone) (2025.11.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Requirement already satisfied: colorama in c:\users\admin\miniconda3\envs\pystudy_env\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai>=0.3.11->langchain-pinecone) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Pinecone 클라이언트 생성
from langchain_pinecone import PineconeVectorStore
import os

PINECONE_INDEX_NAME = os.getenv('PINECONE_INDEX_NAME')
PINECONE_NAMESPACE = os.getenv('PINECONE_NAMESPACE')
PINECONE_API_KEY = os.getenv('PINECONE_API_KEY')

vector_db = PineconeVectorStore.from_documents(
    documents[:30000],  # 업로드할 문서 리스트
    embeddings, # 사용할 임베딩 모델
    index_name=PINECONE_INDEX_NAME,
    namespace=PINECONE_NAMESPACE, # 데이터를 구분 보관할 네임스페이스
    pinecone_api_key=PINECONE_API_KEY
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[18], line 9
#       6 PINECONE_NAMESPACE = os.getenv('PINECONE_NAMESPACE')
#       7 PINECONE_API_KEY = os.getenv('PINECONE_API_KEY')
# ----> 9 vector_db = PineconeVectorStore.from_documents(
#      10     documents[:30000],  # 업로드할 문서 리스트
#      11     embeddings, # 사용할 임베딩 모델
#      12     index_name=PINECONE_INDEX_NAME,
#      13     namespace=PINECONE_NAMESPACE, # 데이터를 구분 보관할 네임스페이스
#      14     pinecone_api_key=PINECONE_API_KEY
#      15 )
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\vectorstores\base.py:813, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     810     if any(ids):
#     811         kwargs["ids"] = ids
# --> 813 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_pinecone\vectorstores.py:978, in PineconeVectorStore.from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, async_req, id_prefix, **kwargs)
#     975 pinecone_index = cls.get_pinecone_index(index_name, pool_threads)
#     976 pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
# --> 978 pinecone.add_texts(
#     979     texts,
#     980     metadatas=metadatas,
#     981     ids=ids,
#     982     namespace=namespace,
#     983     batch_size=batch_size,
#     984     embedding_chunk_size=embeddings_chunk_size,
#     985     async_req=async_req,
#     986     id_prefix=id_prefix,
#     987     **(upsert_kwargs or {}),
#     988 )
#     989 return pinecone
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_pinecone\vectorstores.py:357, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     355 chunk_ids = ids[i : i + embedding_chunk_size]
#     356 chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 357 embeddings = self._embedding.embed_documents(chunk_texts)
#     358 vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
#     359 if async_req:
#     360     # Runs the pinecone upsert asynchronously.
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_openai\embeddings\base.py:709, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     706 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     707 # This could be optimized to avoid double work when all texts are short enough.
#     708 engine = cast(str, self.deployment)
# --> 709 return self._get_len_safe_embeddings(
#     710     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     711 )
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_openai\embeddings\base.py:576, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     574 # Make API call with this batch
#     575 batch_tokens = tokens[i:batch_end]
# --> 576 response = self.client.create(input=batch_tokens, **client_kwargs)
#     577 if not isinstance(response, dict):
#     578     response = response.model_dump()
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for text-embedding-3-small in organization org-tEkN7kkb6kFBT1jbUmEAuN0y on tokens per min (TPM): Limit 1000000, Used 982799, Requested 154363. Please try again in 8.229s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
# 유사도 검색

# 클라이언트 객체 생성
vector_db = PineconeVectorStore(
    embedding=embeddings,
    index_name=PINECONE_INDEX_NAME,
    namespace=PINECONE_NAMESPACE,
    pinecone_api_key=PINECONE_API_KEY
)

results = vector_db.similarity_search(
    "소고기의 육즙과 향긋한 허브향이 어우러져 깊은 풍미를 내는 음식입니다.",
    k=10,
    namespace=PINECONE_NAMESPACE)
results
# Out:
# [Document(id='4e14a4f7-354a-4cd5-9fa1-1018ffe40979', metadata={'row': 78.0, 'source': './winemag-data-130k-v2.csv'}, page_content=": 78\ncountry: US\ndescription: Some rosés are made simply by bleeding the juice from the fermenter, to concentrate the remaining wine. Whether or not that is the case here, the wine has the simple pleasant lightly candied strawberry flavors one might expect from such a technique. It's fruity and undemanding. Drink up.\ndesignation: Rosé of\npoints: 86\nprice: 25.0\nprovince: Oregon\nregion_1: Eola-Amity Hills\nregion_2: Willamette Valley\ntaster_name: Paul Gregutt\ntaster_twitter_handle: @paulgwine\ntitle: Z'IVO 2015 Rosé of Pinot Noir (Eola-Amity Hills)\nvariety: Pinot Noir\nwinery: Z'IVO"),
#  Document(id='200593a6-ae22-4277-aab4-3b5a14c564d4', metadata={'row': 805.0, 'source': './winemag-data-130k-v2.csv'}, page_content=': 805\ncountry: US\ndescription: Bone dry and replete with skin flavors of pear and grapefruit pith, this is perfect for those who want to keep their alcohol consumption down without turning to a sweeter style of wine. Try it with grilled sausages and sauerkraut.\ndesignation: \npoints: 90\nprice: 15.0\nprovince: Oregon\nregion_1: Oregon\nregion_2: Oregon Other\ntaster_name: Paul Gregutt\ntaster_twitter_handle: @paulgwine\ntitle: Firesteed 2012 Riesling (Oregon)\nvariety: Riesling\nwinery: Firesteed'),
#  Document(id='dc5b65cb-3c4c-4d95-9cd2-01ffe02ffcf1', metadata={'row': 884.0, 'source': './winemag-data-130k-v2.csv'}, page_content=": 884\ncountry: US\ndescription: Pretty dark in color and full bodied for a sparkling wine, even one that's majority Pinot Noir. But it's delicious and dry, which surely are prime requisites for any bubbly. Shows ripe, flashy raspberry, strawberry, orange, vanilla, honey, yeast and toast flavors, and the mouthfeel is silky and refined.\ndesignation: Brut Rose\npoints: 90\nprice: 28.0\nprovince: California\nregion_1: Russian River Valley\nregion_2: Sonoma\ntaster_name: \ntaster_twitter_handle: \ntitle: J Vineyards & Winery NV Brut Rose Sparkling (Russian River Valley)\nvariety: Sparkling Blend\nwinery: J Vineyards & Winery"),
#  Document(id='5cebeeaa-c927-4c0a-8391-5247975153d9', metadata={'row': 34.0, 'source': './winemag-data-130k-v2.csv'}, page_content=': 34\ncountry: US\ndescription: This shows a tart, green gooseberry flavor that is similar to New Zealand Sauvignon Blanc. Other notes include tropical fruit, orange and honey. Unoaked, with a splash of Muscat, this has commendable dryness and acidity.\ndesignation: \npoints: 86\nprice: 20.0\nprovince: California\nregion_1: Sonoma Valley\nregion_2: Sonoma\ntaster_name: \ntaster_twitter_handle: \ntitle: Envolve 2011 Sauvignon Blanc (Sonoma Valley)\nvariety: Sauvignon Blanc\nwinery: Envolve'),
#  Document(id='c725105a-9736-4957-a39c-da558d798d70', metadata={'row': 654.0, 'source': './winemag-data-130k-v2.csv'}, page_content=': 654\ncountry: France\ndescription: Freshly cut red, yellow and green apples make both nose and palate very fruity. The dry palate with its lemony freshness and open aspect lets all the apple flavors shine and inflects them here and there with baked and dried apple, too. Wonderfully fruity and pure.\ndesignation: Rosacker Grand Cru\npoints: 92\nprice: 43.0\nprovince: Alsace\nregion_1: Alsace\nregion_2: \ntaster_name: Anne Krebiehl\xa0MW\ntaster_twitter_handle: @AnneInVino\ntitle: Sipp Mack 2014 Rosacker Grand Cru Riesling (Alsace)\nvariety: Riesling\nwinery: Sipp Mack'),
#  Document(id='2a6e6bd6-9fed-48a7-b9e6-f51cc5d69e14', metadata={'row': 958.0, 'source': './winemag-data-130k-v2.csv'}, page_content=': 958\ncountry: Spain\ndescription: Crisp plum and red-bell-pepper aromas lead to a healthy, mostly fresh palate with some weight to it. A mix of citrus and red-plum flavors ends long, without much, if any, unwanted pithiness or bitterness.\ndesignation: Wine Wings Garnacha\npoints: 87\nprice: 18.0\nprovince: Northern Spain\nregion_1: Cariñena\nregion_2: \ntaster_name: Michael Schachner\ntaster_twitter_handle: @wineschach\ntitle: Ignacio Marín 2015 Wine Wings Garnacha Rosé (Cariñena)\nvariety: Rosé\nwinery: Ignacio Marín'),
#  Document(id='cd31a54b-b155-468b-8bf9-b18cb7f58ef2', metadata={'row': 942.0, 'source': './winemag-data-130k-v2.csv'}, page_content=': 942\ncountry: US\ndescription: Stewy plum and cherry jam lie at the heart of this densely layered, though silky-smooth wine, light bodied and ethereal despite the ripeness of fruit flavor. It finishes simply and without fuss.\ndesignation: \npoints: 87\nprice: 34.0\nprovince: California\nregion_1: Russian River Valley\nregion_2: Sonoma\ntaster_name: Virginie Boone\ntaster_twitter_handle: @vboone\ntitle: Ektimo Vineyards 2014 Pinot Noir (Russian River Valley)\nvariety: Pinot Noir\nwinery: Ektimo Vineyards'),
#  Document(id='262b686d-519f-4441-88f5-845353bfd9d7', metadata={'row': 971.0, 'source': './winemag-data-130k-v2.csv'}, page_content=': 971\ncountry: France\ndescription: Although it is labeled “Extra Dry” (that is sweeter than Brut), this lively Champagne in its festive little pink bottle is very fresh, with delicious acidity. It finishes lightly, easily.\ndesignation: Pop Rosé Extra Dry\npoints: 85\nprice: 15.0\nprovince: Champagne\nregion_1: Champagne\nregion_2: \ntaster_name: Roger Voss\ntaster_twitter_handle: @vossroger\ntitle: Pommery NV Pop Rosé Extra Dry  (Champagne)\nvariety: Champagne Blend\nwinery: Pommery'),
#  Document(id='b384affb-d40b-4521-a35b-b0826611b5ca', metadata={'row': 726.0, 'source': './winemag-data-130k-v2.csv'}, page_content=': 726\ncountry: Portugal\ndescription: A rose pink colored wine that is dry and with ripe fruit. Its acidity contrasts with the warm red-berry fruit and the edge of tannin. There is a peppery, crisp aftertaste.\ndesignation: Casa de Paços\npoints: 85\nprice: 9.0\nprovince: Vinho Verde\nregion_1: \nregion_2: \ntaster_name: Roger Voss\ntaster_twitter_handle: @vossroger\ntitle: Quinta de Paços 2015 Casa de Paços Rosé (Vinho Verde)\nvariety: Rosé\nwinery: Quinta de Paços'),
#  Document(id='e89f4e92-014e-469f-865a-e43654e7f3e9', metadata={'row': 579.0, 'source': './winemag-data-130k-v2.csv'}, page_content=': 579\ncountry: US\ndescription: This refreshing, well-structured wine offers vivid but light fruit flavors, a crisp balance and mouthwatering texture. It has lots of fresh citrus flavors that will pair well with salty meats and all kinds of seafood.\ndesignation: \npoints: 89\nprice: 13.0\nprovince: California\nregion_1: California\nregion_2: California Other\ntaster_name: Jim Gordon\ntaster_twitter_handle: @gordone_cellars\ntitle: Cupcake 2016 Rosé (California)\nvariety: Rosé\nwinery: Cupcake')]
